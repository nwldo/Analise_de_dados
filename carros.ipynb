# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bases de dados/carros.csv', sep=';')

# %%
df.head(n=5)
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
df.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
estatisticas = df[['Quilometragem', 'Valor']].describe()
estatisticas
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %%
# 7. Obtenha mais informações do dataset com a função info(). Tem alguma coluna com dados nulos? Se sim, qual a coluna e quantos  dados nulos possui?
df.isnull().sum()
# Out:
# Nome              0
# Motor             0
# Ano               0
# Quilometragem    61
# Zero_km           0
# Acessórios        0
# Valor             0
# dtype: int64

# %%
# Para substituir os valores Nan por 0,
df.replace(np.nan, 0, inplace = True)
df.head(n=10)
# Out:
#                Nome                  Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant        Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat           Motor Diesel  1991         5712.0    False
# 2          Crossfox        Motor Diesel V8  1990        37123.0    False
# 3               DS5        Motor 2.4 Turbo  2019            0.0     True
# 4  Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0    False
# 5     Palio Weekend          Motor 1.8 16v  2012        10728.0    False
# 6                A5        Motor 4.0 Turbo  2019            0.0     True
# 7    Série 3 Cabrio           Motor 1.0 8v  2009        77599.0    False
# 8      Dodge Jorney          Motor 3.0 32v  2010        99197.0    False
# 9            Carens  Motor 5.0 V8 Bi-Turbo  2011        37978.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# ...

# %% [markdown]
# 8. Com base no Dataset que estamos trabalhando, defina uma função para mostrar a quilometragem média de todos os carros.  Sabendo  que a formula é:
#
# Km_media = km_total / (ano_atual - ano_fabricação)
#
# A função tem que receber como parâmetros: o dataset e o ano atual.
# Execute a função e mostre o resultado.

# %%
def quilometragem_media(df, ano_atual):
    # Calcular a quilometragem média
    total_quilometragem = df['Quilometragem'].sum()
    total_anos = (ano_atual - df['Ano']).sum()
    km_media = total_quilometragem / total_anos
    return km_media


# Definir o ano atual
ano_atual = 2024

# Calcular e mostrar a quilometragem média
km_media = quilometragem_media(df, ano_atual)
f'A quilometragem média dos carros é: {km_media:.2f} km/ano'
# Out:
# 'A quilometragem média dos carros é: 2698.84 km/ano'

# %% [markdown]
# 9. Utilizando a pesquisa com queries, faça:
#
#
#
#
# e) liste os carros com câmbio automático com valor abaixo de R$ 100.000
#
# f) liste os carros novos com "freios ABS" que custam acima de R$ 100.000
#
# g) liste os carros novos ou usados com km média abaixo de 10.000 km que custam até R$ 100.000

# %%
# a) mostre os carros com motor "Diesel V8"
carros_Diesel_V8 = df[df['Motor'] == 'Motor Diesel V8']
nomes_carros_diesel_v8 = carros_Diesel_V8['Nome']

nomes_carros_diesel_v8
# Out:
# 2                     Crossfox
# 11                     Courier
# 15                         RAM
# 48                        CR-V
# 85                 Grand Siena
# 110               Cadillac XLR
# 120    Classe C 63 AMG Touring
# 122                   Veloster
# 127                      Bongo
# 128                        ASX
# 159                L200 Triton
# 172                    Boxster
# 182                     Alsvin
# 187           Aston Martin DB7
# 191            Vantage Volante
# 193            Palio Adventure
# 201                   Classe B
# 202                     Parati
# 227                         X1
# 231                   Veracruz
# 249                    LS 460L
# Name: Nome, dtype: object

# %%
# b) pesquise por carros com motor 1.0 8v usados com preço inferior a R$ 100.000
carros_filtrados = df[(df['Motor'] == 'Motor 1.0 8v') & (df['Zero_km'] == False) & (df['Valor'] < 100000)]

carros_filtrados
# Out:
#                                  Nome         Motor   Ano  Quilometragem  \
# 18                               XC90  Motor 1.0 8v  2016        37086.0
# 30                     Classe SLS AMG  Motor 1.0 8v  1997        30163.0
# 32                              Linea  Motor 1.0 8v  2018        17720.0
# 38                         California  Motor 1.0 8v  2009         5526.0
# 71                       Cadillac ELR  Motor 1.0 8v  2007        84992.0
# 144                    Passat Variant  Motor 1.0 8v  1991       115930.0
# 162                         C4 Pallas  Motor 1.0 8v  1998        76453.0
# 170  Effa Hafei Picape Cabine Simples  Motor 1.0 8v  1993        38620.0
# 197                     Série 1 Coupé  Motor 1.0 8v  1993        87161.0
# 199                               C30  Motor 1.0 8v  2001        55738.0
# 214                          Classe A  Motor 1.0 8v  1999        14046.0
# 228                               GLA  Motor 1.0 8v  1991         8394.0
#
# ...

# %%
# pesquise por carros com km média de até 10.000 km com Motor 1.8 16v
carros_filtrados_media = df[(df['Motor'] == 'Motor 1.8 16v') & (df['Quilometragem'] <= 10000)]

carros_filtrados_media
# Out:
#                      Nome          Motor   Ano  Quilometragem  Zero_km  \
# 42                 Optima  Motor 1.8 16v  2019            0.0     True
# 88                 Fusion  Motor 1.8 16v  2019            0.0     True
# 118              Ford Ka+  Motor 1.8 16v  2006         9595.0    False
# 134      Aston Martin DB9  Motor 1.8 16v  1996         4821.0    False
# 140                   i30  Motor 1.8 16v  2019            0.0     True
# 143  Phantom I Phantom II  Motor 1.8 16v  2019            0.0     True
# 174     Lamborghini Jalpa  Motor 1.8 16v  2018         9146.0    False
#
#                                             Acessórios      Valor
# 42   ['Central multimídia', 'Ar condicionado', 'Tet...   86641.34
# 88   ['Controle de tração', 'Câmbio automático', 'F...  100380.28
# 118  ['Sensor crepuscular', 'Piloto automático', 'C...   87830.41
# 134  ['Ar condicionado', 'Vidros elétricos', '4 X 4...  104929.88
# 140  ['Câmbio automático', 'Controle de estabilidad...   86224.10
# ...

# %%
# d) liste os tipos de motores cadastrados 
motores_cadastrados = df['Motor'].unique()

motores_cadastrados
# Out:
# array(['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8',
#        'Motor 2.4 Turbo', 'Motor 1.8 16v', 'Motor 1.0 8v',
#        'Motor 3.0 32v', 'Motor 5.0 V8 Bi-Turbo', 'Motor Diesel V6',
#        'Motor V6', 'Motor V8', 'Motor 2.0 16v'], dtype=object)

# %%
# e) liste os carros com câmbio automático com valor abaixo de R$ 100.000
carros_automaticos = df[(df['Acessórios'].str.contains('Câmbio automático')) & (df['Valor'] < 100000)]

carros_automaticos
# Out:
#                  Nome                  Motor   Ano  Quilometragem  Zero_km  \
# 2            Crossfox        Motor Diesel V8  1990        37123.0    False
# 4    Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0    False
# 6                  A5        Motor 4.0 Turbo  2019            0.0     True
# 9              Carens  Motor 5.0 V8 Bi-Turbo  2011        37978.0    False
# 13                 J5               Motor V6  2019            0.0     True
# ..                ...                    ...   ...            ...      ...
# 246               RS5               Motor V6  1996        55083.0    False
# 247            Cerato               Motor V6  2011        48796.0    False
# 249           LS 460L        Motor Diesel V8  2010        89685.0    False
# 253      Phantom 2013               Motor V8  2014        27505.0    False
# 255        Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
#
#                                             Acessórios     Valor
# ...

# %%
# f) liste os carros novos com "freios ABS" que custam acima de R$ 100.000
carros_automaticos_freios_ABS = df[(df['Acessórios'].str.contains('Freios ABS')) & (df['Valor'] > 100000)]
carros_automaticos_freios ABS
# Out:
#   Cell In[42], line 2
#     carros_automaticos_freios ABS = df[(df['Acessórios'].str.contains('Câmbio automático')) & (df['Valor'] < 10000)]
#                               ^
# SyntaxError: invalid syntax
