# %% [markdown]
# Utilizando  5 datasets trabalhados em aulas anteriores:
# 1. Carros
# 2. Vinhos
# 3. Titanic
# 4. Filmes
# 5. Senso_IBGE
#
# escolha pelo menos 2 gráficos adequados para representar os resultados de seus insights para cada dataset acima  e plote-os.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Foi utilizando esse caminho porque o base de dados está no diretório anterior
df = pd.read_csv('../bases de dados/dados_senso_ibge_2015.csv', sep=',')

# %%
df.head(n=5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
# Gráfico 1: Dispersão - Idade vs. Renda, colorindo por sexo
plt.figure(figsize=(10, 6))
plt.scatter(df['Idade'], df['Renda'], c=df['Sexo'], cmap='viridis', alpha=0.7)
plt.xlabel('Idade')
plt.ylabel('Renda')
plt.title('Relação entre Idade e Renda por Sexo')
plt.colorbar(label='Sexo (0: Feminino, 1: Masculino)')
plt.grid(True)
plt.show()

# %% [markdown]
# Gráfico de dispersão: Idade vs. Renda, colorindo os pontos por sexo.
# Isso nos permitirá visualizar a relação entre idade e renda e identificar possíveis diferenças entre homens e mulheres.
#
# É possível visualizar pelo gráfico há uma correlação positiva entre idade e renda. A renda aumenta quando se está na faixa que corresponde a população economicamente ativa.
# Em média a renda está entre 0 à 2500

# %%
grouped_data = df.groupby('Anos de Estudo')['Renda'].apply(list)

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(grouped_data.values)
plt.xticks(range(1, len(grouped_data) + 1), grouped_data.index)
plt.xlabel('Anos de Estudo')
plt.ylabel('Renda')
plt.title('Distribuição da Renda por Nível de Escolaridade')
plt.grid(True)
plt.show()

# %% [markdown]
# Gráfico Boxplot:
#
# A linha central da caixa que representa a mediana pode-se observar que, em geral, à medida que o número de anos de estudo aumenta, a mediana da renda também tende a aumentar. Isso sugere uma relação positiva entre o nível de escolaridade e a renda.
#
# Dispersão dos Dados: A altura da caixa representa o intervalo interquartil (IQR), que contém 50% dos dados.
# As Caixas (que contêm Dispersão dos Dados) mais altas indicam uma maior dispersão dos valores de renda dentro daquele nível de escolaridade. A dispersão da renda tende a aumentar à medida que o nível de escolaridade aumenta, o que sugere que, embora a renda média aumente com mais anos de estudo, a variação da renda também se torna maior.
