# %% [markdown]
# # Dataset: ANAC - Dados dos vôos domésticos do ano de 2020
# https://sas.anac.gov.br/sas/downloads/view/frmDownload.aspx?tema=14

# %% [markdown]
# ## Etapa de preparação dos dados
# <strong>Os dados para análise estão separados em meses, então irei fazer o procedimento de Consolidar arquivos CSV.
#
# - Para realizar esse procedimento baixe todos os arquivos pelo link acima;
# - Na pastas dos arquivos abra o "cmd";
# - Digite os códigos de acordo a imagem abaixo;
# - Será gerado um único arquivo csv.</strong>

# %%
from IPython.display import Image, display

# %%
display(Image(filename='preparacao_dados_1.png'))

# %%
display(Image(filename='preparacao_dados_2.png'))

# %%
import pandas as pd

# %%
import os
import glob
import pandas as pd
#set working directory
os.chdir("C:\Users\regenildo.oliveira\Documents\dev\Analise_de_Dados\anac\anac_10207664")

#find all csv files in the folder
#use glob pattern matching -> extension = 'csv'
#save result in list -> all_filenames
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#print(all_filenames)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='latin-1')
# Out:
#   Cell In[8], line 5
#     os.chdir("C:\Users\regenildo.oliveira\Documents\dev\Analise_de_Dados\anac\anac_10207664")
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
url ='https://github.com/Nwldo/Analise_de_dados/blob/main/anac/tarifas_aereas_2020.csv'

# %%
df = pd.read_csv('202001.CSV', sep=';', encoding='latin-1')
df.head(n=6)
# Out:
#    Ano de Referência  Mês de Referência ICAO Empresa Aérea  \
# 0               2020                  1                AZU
# 1               2020                  1                AZU
# 2               2020                  1                AZU
# 3               2020                  1                AZU
# 4               2020                  1                AZU
# 5               2020                  1                AZU
#
#   ICAO Aeródromo Origem ICAO Aeródromo Destino Tarifa-N  \
# 0                  SBAC                   SBCF    693,9
# 1                  SBAC                   SBFN    404,9
# 2                  SBAC                   SBGL   1138,9
# 3                  SBAC                   SBGL    283,9
# 4                  SBAC                   SBGL    459,9
# 5                  SBAC                   SBGL    512,9
#
#    Assentos Comercializados
# 0                         2
# 1                         2
# 2                         1
# 3                         1
# ...

# %%
df.replace({',': '.'}, regex=True)
# Out:
#                           Ano de Referencia;Mes de Referencia;ICAO Empresa Aerea;ICAO Aerodromo Origem;ICAO Aerodromo Destino;Tarifa-N;Assentos Comercializados
# 2020;1;AZU;SBAC;SBCF;693                                                 9;2
# 2020;1;AZU;SBAC;SBFN;404                                                 9;2
# 2020;1;AZU;SBAC;SBGL;1138                                                9;1
# 2020;1;AZU;SBAC;SBGL;283                                                 9;1
# 2020;1;AZU;SBAC;SBGL;459                                                 9;2
# ...                                                                      ...
# 2020;4;GLO;SBBR;SBFL;523                                                 9;1
# 2020;4;GLO;SBBR;SBFL;526                                                 9;1
# 2020;4;GLO;SBBR;SBFL;546                                                 9;1
# 2020;4;GLO;SBBR;SBFL;599                                                 9;3
# ...

# %%
import csv

# %%
df1.head(n=50)
# Out:
#                                       <!DOCTYPE html>
# 0                                               <html
# 1                                           lang="en"
# 2     data-color-mode="auto" data-light-theme="lig...
# 3     data-a11y-animated-images="system" data-a11y...
# 4                                                   >
# 5                                              <head>
# 6                              <meta charset="utf-8">
# 7     <link rel="dns-prefetch" href="https://githu...
# 8     <link rel="dns-prefetch" href="https://avata...
# 9     <link rel="dns-prefetch" href="https://githu...
# 10    <link rel="dns-prefetch" href="https://user-...
# 11    <link rel="preconnect" href="https://github....
# 12    <link rel="preconnect" href="https://avatars...
# 13    <link crossorigin="anonymous" media="all" re...
# 14      <link crossorigin="anonymous" media="all" ...
# 15      <link crossorigin="anonymous" media="all" ...
# ...

# %%
from IPython.display import display
display(df.head())
# Out:
#                                      <!DOCTYPE html>
# 0                                              <html
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...
# 3    data-a11y-animated-images="system" data-a11y...
# 4                                                  >

# %%
df.head(n=5)
# Out:
#                                      <!DOCTYPE html>
# 0                                              <html
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...
# 3    data-a11y-animated-images="system" data-a11y...
# 4                                                  >

# %% [markdown]
# ## Para corregir esse erro foi necessário realizar limpeza nos dados, pois a coluna "Assentos" estava com virgula em vez de ponto;
# ## Para realizar o procedimento usei o bloco de notas com a função "substituir"

# %%
display(Image(filename='preparacao_dados_3.png'))

# %%
df.replace()

# %%
# https://gist.github.com/boniattirodrigo/67429ada53b7337d2e79
import unicodedata
import re

"""
A remoção de acentos foi baseada em uma resposta no Stack Overflow.
http://stackoverflow.com/a/517974/3464573
"""

def removerAcentosECaracteresEspeciais(palavra):

    # Unicode normalize transforma um caracter em seu equivalente em latin.
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
    return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)

print(removerAcentosECaracteresEspeciais('atenção'))
# Out:
# atencao
# <>:17: SyntaxWarning: invalid escape sequence '\]'
# <>:17: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\regenildo.oliveira\AppData\Local\Temp\ipykernel_7300\3736651213.py:17: SyntaxWarning: invalid escape sequence '\]'
#   return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)
